# %%
import sqlite3
import logging
from pathlib import Path
from datetime import datetime, timedelta, timezone
from typing import List, Dict
import pandas as pd

# %%
db_path = Path.cwd().parent / "data" / "articles.db"
connection = sqlite3.connect(db_path)
query = "SELECT * FROM articles"

df = pd.read_sql_query(query, connection)

connection.close()

df
# Out:
#       id                                                url  \
# 0    182  https://towardsdatascience.com/10-statistical-...
# 1    183  https://towardsdatascience.com/how-to-maximize...
# 2    184  https://towardsdatascience.com/the-model-valid...
# 3    185  https://towardsdatascience.com/a-beginners-gui...
# 4    186  https://towardsdatascience.com/introducing-shi...
# ..   ...                                                ...
# 137  319  https://deepmind.google/blog/gemini-omni-1-1-f...
# 138  320  https://deepmind.google/blog/piloting-the-worl...
# 139  321  https://deepmind.google/blog/intelligent-trans...
# 140  322  https://deepmind.google/blog/from-atari-to-eve...
# 141  323  https://deepmind.google/blog/introducing-gemin...
#
#                                                  title  \
# 0               10 Statistical Traps We Often Overlook
# 1                          How to Maximize GPT-6 Astra
# 2    The Model Validation Playbook for GenAI: Lesso...
# 3                   A Beginner’s Guide to World Models
# 4                                   Introducing ShipAI
# ..                                                 ...
# 137  Gemini Omni 1.1 Flash lets you build with more...
# 138  Piloting the world's first double-blind AI eva...
# 139  Intelligent transcription with Gemini 3.5 Tran...
# 140  From Atari to EVE Online: Building on 15 Years...
# 141                       Introducing Gemini 3.7 Flash
#
#                                                content  \
# 0    10 Statistical Traps We Often Overlook\nStatis...
# 1    How to Maximize GPT-6 Astra\nMy first impressi...
# 2    The Model Validation Playbook for GenAI: Lesso...
# 3    A Beginner’s Guide to World Models\nLearn how ...
# 4    Introducing ShipAI\nTowards Data Science launc...
# ..                                                 ...
# 137  Gemini Omni 1.1 Flash lets you build with more...
# 138  Piloting the world's first double-blind AI eva...
# 139  Intelligent transcription with Gemini 3.5 Tran...
# 140  From Atari to EVE Online: Building on 15 Years...
# 141  Introducing Gemini 3.7 Flash\nToday, we’re bui...
#
#                 source_site           scraped_at
# 0    towardsdatascience.com  2026-09-09 12:12:27
# 1    towardsdatascience.com  2026-09-09 12:12:27
# 2    towardsdatascience.com  2026-09-09 12:12:27
# 3    towardsdatascience.com  2026-09-09 12:12:27
# 4    towardsdatascience.com  2026-09-09 12:12:27
# ..                      ...                  ...
# 137         deepmind.google  2026-09-09 12:17:12
# 138         deepmind.google  2026-09-09 12:17:13
# 139         deepmind.google  2026-09-09 12:17:13
# 140         deepmind.google  2026-09-09 12:17:13
# 141         deepmind.google  2026-09-09 12:17:14
#
# [142 rows x 6 columns]

# %%
db_path = Path.cwd().parent / "data" / "articles.db"
connection = sqlite3.connect(db_path)
query_2 = "SELECT COUNT() as Number_of_articles FROM articles"

df = pd.read_sql_query(query_2, connection)

connection.close()

df
# Out:
#    Number_of_articles
# 0                 142
